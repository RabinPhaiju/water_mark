# %%
import matplotlib.pyplot as plt

# %%
q = [1.5, 1, 0.98,0.95,0.9,0.85,0.78,0.6]
level = [34.37,34.27,34.23,34.25,34.20,34.22,34.23,34.30
]

plt.plot(q, level)
plt.title('COMPARISON OF 2-LEVEL DWT FOR RECOVERED IMAGE')
plt.xlabel('q')
plt.ylabel('PSNR Level 2')
plt.show()
